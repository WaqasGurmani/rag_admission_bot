# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
# Out:
# WARNING:tensorflow:From C:\Users\Waqas\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
loader = PyPDFLoader(
    "Leggend_College_Admission_Information.pdf"
)
documents = loader.load()

print(f"Total pages loaded: {len(documents)}")
# Out:
# Total pages loaded: 1

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)

print(f"Total chunks created: {len(chunks)}")
# Out:
# Total chunks created: 4

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# C:\Users\Waqas\AppData\Local\Temp\ipykernel_23272\1474760240.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(

# %%
#FAISS index create + SAVE

# %%
vectorstore = FAISS.from_documents(chunks, embeddings)

vectorstore.save_local("vectorstore")

print("✅ Vectorstore saved successfully")
# Out:
# ✅ Vectorstore saved successfully
